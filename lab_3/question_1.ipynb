# %%
# Yadukrishnan
# 21BAI1210

# %%
#Ignoring TF warning messages
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
import tensorflow as tf
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from keras.models import Sequential
import keras.layers

# %%
X,y = make_circles(n_samples=1000, factor=0.5, noise = 0.1)
plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
X.shape
# Out:
# (1000, 2)

# %%
nn = Sequential()
nn.add(keras.layers.Dense(units=5, activation='relu', input_shape=(2,)))
nn.add(keras.layers.Dense(units=1, activation='sigmoid'))

# %%
nn.compile(optimizer='sgd', loss = keras.losses.BinaryCrossentropy(), metrics=keras.metrics.BinaryAccuracy())

# %%
nn.fit(X, y, batch_size=16, epochs=20, verbose=True)
# Out:
# Epoch 1/20
#  1/63 [..............................] - ETA: 1:42 - loss: 0.6829 - binary_accuracy: 0.5000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706977118.040121   90446 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 63/63 [==============================] - 2s 5ms/step - loss: 0.6772 - binary_accuracy: 0.5250
# Epoch 2/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6752 - binary_accuracy: 0.5930
# Epoch 3/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6733 - binary_accuracy: 0.6000
# Epoch 4/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6713 - binary_accuracy: 0.6050
# Epoch 5/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6694 - binary_accuracy: 0.6030
# Epoch 6/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6672 - binary_accuracy: 0.6040
# ...
