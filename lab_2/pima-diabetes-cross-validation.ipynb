# %%
# Yadukrishnan
# 21BAI1210

# %%
from keras.models import Sequential 
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd 
import keras
# Out:
# 2024-02-02 17:59:47.066336: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-02 17:59:47.066439: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-02 17:59:47.347367: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset = pd.read_csv('/kaggle/input/pima-indians-diabetes-database/diabetes.csv')

# %%
#X and Y
X=np.array(dataset.drop('Outcome',axis=1))
Y=np.array(dataset['Outcome'])

# %%
kfold=StratifiedKFold(n_splits=10,shuffle=True,random_state=7)
tot_scores=[]

for train,test in kfold.split(X,Y):
    model=Sequential()
    model.add(Dense(12,input_dim=8,kernel_initializer='uniform',activation='relu'))
    model.add(Dense(1,kernel_initializer='uniform',activation='sigmoid'))

    model.compile(loss=keras.losses.BinaryCrossentropy(),metrics=keras.metrics.BinaryAccuracy(),optimizer='adam')

    model.fit(X[train],Y[train],epochs=100,batch_size=10,verbose=0)

    scores=model.evaluate(X[test],Y[test],verbose=0)
    tot_scores.append(scores[1]*100)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706896816.215068     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
sum(tot_scores)/len(tot_scores) #21BAI1210
# Out:
# 74.74709391593933
